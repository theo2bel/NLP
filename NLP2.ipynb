# %%
import os
import nltk
from nltk import word_tokenize, pos_tag

# Download NLTK data (if not already downloaded)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to identify adverbs in a text
def identify_adverbs(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    adverbs = [word for word, pos in tagged_words if pos.startswith('RB')]
    return adverbs

# Function to process files in a folder
def process_folder(folder_path):
    adverbs_list = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()
                adverbs = identify_adverbs(text)
                adverbs_list.append(adverbs)
    return adverbs_list
# Out:
# [nltk_data] Downloading package punkt to /home/theo2bel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/theo2bel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Path to the "neg" and "pos" folders
neg_folder_path = '/home/theo2bel/Downloads/review_polarity/txt_sentoken/neg'
pos_folder_path = '/home/theo2bel/Downloads/review_polarity/txt_sentoken/pos'

# Process negative reviews
neg_adverbs = process_folder(neg_folder_path)
print("Adverbs in negative reviews:")
print(neg_adverbs)

# Process positive reviews
pos_adverbs = process_folder(pos_folder_path)
print("\nAdverbs in positive reviews:")
print(pos_adverbs)
# Out:
# Adverbs in negative reviews:
# [['billy', 'usually', 'well', 'lately', 'tellingly', 'very', 'unfortunately', 'away', 'not', 'progressively', 'more', 'finally', 'billy', 'finally', 'very', 'well', 'never', 'especially', 'also', 'about', 'however', 'suddenly', 'accidentally', 'subsequently', 'desperately', 'even', "n't", 'even', 'mostly', 'more', 'not', 'away', 'more', 'potentially', 'mostly', 'always', 'lightly', 'billy', 'then', 'tiresomely', 'admittedly', 'very', 'here', "n't", 'down', 'directly', 'else', 'not', 'not', 'together', 'noticably', 'most', "n't", 'even', 'down', 'ago', 'meanwhile', 'mostly', 'just', 'even', 'finally', 'molly', 'rousingly', 'then', 'completely', 'too', 'surely', 'once', 'alone', 'once', 'again', 'thoroughly', 'mostly', 'most', 'certainly', "n't", 'up', 'virtually'], ['unfortunately', 'absolutely', 'whatsoever', 'aside', 'out', 'so', 'basically', 'so', 'here', 'as', 'basically', 'much', 'not', 'especially', 'not', 'more', 'bafflingly', 'not', 'partly', 'even', 'too', 'thus', "n't", 'only'], ['more', 'relentlessly', 'just', 'as', 'verhoeven', 'writer', 'not', 'surprisingly', 'just', 'unfortunately', "n't", "n't", 'most', 'ever'], ['not', 'not', 'not', 'even', 'so', 'cynically', 'calculatedly', 'even', 'alternately', 'i', "n't", 'literally', 'berserk', 'frantically', 'only', "n't", 'instead', 'clearly', "n't", 'heinlein', 'most', 'ever', 'ultimately', 'too', 'consistently', 'not', 'even', "n't", 'even', 'therefore', "n't", '*', 'therefore', 'here', "n't", 'even', 'there', 'really', 'there', "n't", 'perhaps', 'increasingly', 'not', 'again', 'again', 'again', 'once', 'twice', 'never', 'really', 'really', 'also', 'irritatingly', 'then', 'away', 'very', "n't", 'genuinely', 'apparently', 'just', 'so', 'relatively', 'not', 'bland'], ['most', 'less', 'less', 'better', 'back', 'only', 'highly', 'often', 'perhaps', 'most', 'even', 'not', 'just', 'also', 'then', 'only', 'blurry', 'not', 'not', 'now', 'just', 'so', 'suddenly', 'else', 'only', 'billy', 'hilly', 'hilly', 'previously', 'more', 'recently', 'also', 'so', 'soon', 'considerably', 'never', 'quite', 'also', 'perhaps', 'even', 'together', 'patently', 'not', 'not', 'around', 'much'], ['ever', 'too', 'soon', 'again', 'badly', 'just', "n't", 'too', 'earlier', "n't", 'too', 'long', 'here', 'never', 'long'], ['even', 'forward', 'also', 'always', 'right', 'always', 'usually', 'even', "n't", 'even', 'even', 'even', 'more', 'else', "n't", 'again', "n't", 'instead', 'possibly', 'unfortunately', "n't", 'either', 'even', 'suppos
 'however', 'i', 'even', 'here', 'as', 'as', 'well', 'well', 'very', 'atmosphere', 'even', 'sometimes', 'downright', 'even', 'not', 'even', 'only', 'well', 'only', 'quite', 'not', 'even', 'instead', 'really', "n't", 'seriously', 'still', "n't"], ["n't", 'surprisingly', 'terminally', 'reilly', 'exceedingly', 'almost', 'so', 'quite', 'afterward', 'often', 'perhaps', 'here', 'perhaps', 'certainly', 'totally', 'once', 'more', 'finally', 'not', 'suitably', 'close', 'surprisingly', 'apparently', 'maybe', 'not', 'little', "n't"], ['possibly', 'away', "n't", 'never', 'well', 'very', 'well', 'painfully', 'ironically', 'finally', 'morosely', 'too', 'far', 'first', 'then', 'halfheartedly', 'then', 'hard', "n't", 'anyway', 'truthfully', 'then', 'eventually', 'back', 'ugly', 'further', 'not', 'not', 'not', 'no', 'longer', 'anyway', 'not', 'so', 'actually', 'appropriately', 'enough', 'late', 'so', 'so', 'so', 'hard', "n't", 'warren', 'callously', 'instead', 'then', 'not', 'not', 'very', 'not', 'embarrassingly', 'not', 'eventually', 'too', 'even', 'along', 'much', 'still', 'very', 'first', 'then', 'then', 'else', 'probably', 'anyway', 'too', "n't", 'much', 'just', 'just', "n't"], ['before', 'entirely', 'however', 'so', 'unfortunately', 'pretty', 'just', 'actually', 'somewhat', 'more', 'even', 'probably', 'nearly', 'very', 'instead', 'around', 'only', 'loosely', 'pretty', 'then', 'not', 'quite', 'effectively', 'very', 'once', "n't", 'immediately', 'instead', 'out', 'somewhere', 'quite', 'soon', 'however', 'therefore', 'often', 'even', 'even', "n't", 'late', "n't", 'anymore', 'cautiously', 'not', 'instead', 'entirely', 'along', 'even', 'always', 'not', 'thankfully', 'already', 'so', 'awkward', 'highly', 'most', 'usually', 'here', 'definitely', 'not', 'ever', 'sure', 'better', 'here', 'never', 'quite', "n't", 'that', 'not', 'early', 'too', 'even', 'too', 'very', 'though', "n't", 'bart'], ['well', 'suddenly', "n't", 'however', 'recently', 'never', 'before', 'not', 'quite', 'more', 'nearly', 'never', 'boringly', 'instead', 'nicely', 'rather', 'hurriedly', 'well', ' ...

# %%
import nltk
from nltk.corpus import sentiwordnet as swn

# Download the necessary NLTK data (if not already downloaded)
nltk.download("sentiwordnet")

# Function to score adverbs using SentiWordNet
def score_adverbs_with_swn(adverbs):
    adverb_scores = []
    for text in adverbs:
        score_text=[]
        for adverb in text:
            synsets = list(swn.senti_synsets(adverb))
            if synsets:
                # Take the first synset as a simple example (you can combine multiple synsets)
                synset = synsets[0]
                positive_score = synset.pos_score()
                negative_score = synset.neg_score()
                objective_score = synset.obj_score()
                score_text.append((positive_score,negative_score,objective_score))
        adverb_scores.append(score_text)
    return adverb_scores


# Score the adverbs
adverb_scores_pos = score_adverbs_with_swn(pos_adverbs)
adverb_scores_neg = score_adverbs_with_swn(neg_adverbs)


# Now we make a sum of the negative and positive scores for a text
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /home/theo2bel/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!

# %%
scores_pos = [sum([float(i[0]) - float(i[1]) for i in j])/len(j) for j in adverb_scores_pos ]
# We divide by the length because if the text is much longer than others, it is more equilibrated so it does not mean anything
# And here there are 1000 texts in both positive and negative reviews so we don't have to divide by the number of texts

# %%
scores_neg = [sum([float(i[0]) - float(i[1]) for i in j])/len(j) for j in adverb_scores_neg ]

# %%
len(scores)
# Out:
# 1000

# %%
sum(scores_neg)
# Out:
# 16.88124874118352

# %%
sum(scores_pos)
# Out:
# 21.71405661495686

# %% [markdown]
# The scores are quite near, so it is not sufficient to score as we did.
